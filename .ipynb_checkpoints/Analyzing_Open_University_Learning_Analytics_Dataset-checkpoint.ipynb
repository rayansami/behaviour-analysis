# %% [markdown]
# # Analyzing Open University Learning Analytics Dataset

# %% [markdown]
# #### Reference: https://archive.ics.uci.edu/ml/datasets/Open+University+Learning+Analytics+dataset#
#
# #### Complete data and data description: https://analyse.kmi.open.ac.uk/open_dataset
#
# Open University Learning Analytics Dataset (OULAD) contains data about courses, students and their interactions with Virtual Learning Environment (VLE) for seven selected courses (called modules)----AAA, BBB, CCC, DDD, EEE, FFF, GGG. Presentations of courses start in February and October - they are marked by 'B' and 'J' respectively (2013B, 2013J, 2014B, 2014J). The dataset consists of tables connected using unique identifiers. Dataset is stored in several csv files
# <ol>
#     <li>assessements.csv</li>
#     <li>courses.csv</li>
#     <li>studentAssessment.csv</li>
#     <li>studentInfo.csv</li>
#     <li>studentRegistration.csv</li>
#     <li>studentVle.csv</li>
#     <li>vle.csv</li>
# </ol>

# %%
# !ls
# Out:
# Analyzing_Open_University_Learning_Analytics_Dataset.ipynb
# Dataset
# README.md

# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
plt.rcdefaults()
import seaborn as sns
# %matplotlib inline

#bokeh
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.plotting import figure, output_file, show, ColumnDataSource
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
student_info = pd.read_csv('Dataset/studentInfo.csv')
student_assessment = pd.read_csv('Dataset/studentAssessment.csv')
student_registration = pd.read_csv('Dataset/studentRegistration.csv')
student_vle = pd.read_csv('Dataset/studentVle.csv')
assessments = pd.read_csv('Dataset/assessments.csv')
courses = pd.read_csv('Dataset/courses.csv')
vle = pd.read_csv('Dataset/vle.csv')

# %%
print('Courses     : ',courses.shape[0])
print('Assessments : ',assessments.shape[0])
print('vle(Virtual Learning Environment) : ',vle.shape[0])
print('Student Info         : ',student_info.shape[0])
print('student Assessment   : ',student_assessment.shape[0])
print('student Registration : ',student_registration.shape[0])
print('student Vle          : ',student_vle.shape[0])
# Out:
# Courses     :  22
# Assessments :  206
# vle(Virtual Learning Environment) :  6364
# Student Info         :  32593
# student Assessment   :  173912
# student Registration :  32593
# student Vle          :  10655280

# %%
student_info.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# 3               60          N         Pass
# 4               60          N         Pass

# %%
student_assessment.head()
# Out:
#    id_assessment  id_student  date_submitted  is_banked score
# 0           1752       11391              18          0    78
# 1           1752       28400              22          0    70
# 2           1752       31604              17          0    72
# 3           1752       32885              26          0    69
# 4           1752       38053              19          0    79

# %%
student_registration.head()
# Out:
#   code_module code_presentation  id_student date_registration  \
# 0         AAA             2013J       11391              -159
# 1         AAA             2013J       28400               -53
# 2         AAA             2013J       30268               -92
# 3         AAA             2013J       31604               -52
# 4         AAA             2013J       32885              -176
#
#   date_unregistration
# 0                   ?
# 1                   ?
# 2                  12
# 3                   ?
# 4                   ?

# %%
student_vle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
assessments.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type date  weight
# 0         AAA             2013J           1752             TMA   19    10.0
# 1         AAA             2013J           1753             TMA   54    20.0
# 2         AAA             2013J           1754             TMA  117    20.0
# 3         AAA             2013J           1755             TMA  166    20.0
# 4         AAA             2013J           1756             TMA  215    30.0

# %%
courses.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
vle.head()
# Out:
#    id_site code_module code_presentation activity_type week_from week_to
# 0   546943         AAA             2013J      resource         ?       ?
# 1   546712         AAA             2013J     oucontent         ?       ?
# 2   546998         AAA             2013J      resource         ?       ?
# 3   546888         AAA             2013J           url         ?       ?
# 4   547035         AAA             2013J      resource         ?       ?

# %%
student_info.shape
# Out:
# (32593, 12)

# %%
student_assessment.shape
# Out:
# (173912, 5)

# %%
student_registration.shape
# Out:
# (32593, 5)

# %%
student_vle.shape
# Out:
# (10655280, 6)

# %%
assessments.shape
# Out:
# (206, 6)

# %%
courses.shape
# Out:
# (22, 3)

# %%
vle.shape
# Out:
# (6364, 6)

# %%
def tabel(colname, rowname, data):
    tab = pd.crosstab(data[colname], data[rowname]) 
    tab.reset_index(level=0, inplace=True)
    
    tab['total'] = 0
    cols = [colname]
    for col in data[rowname].unique():
        tab['total'] = tab['total'] + tab[col]    
        cols.append(col)
    cols.append('total')
    #tab.columns = cols
    for col in data[rowname].unique():
        ratiocol = col + '_%'
        tab[ratiocol] = round(100 * tab[col] / tab['total'], 2)
    return tab

# %%
colname = 'age_band'
tabel(colname, 'final_result', student_info)
# Out:
# final_result age_band  Distinction  Fail  Pass  Withdrawn  total  Pass_%  \
# 0                0-35         1863  5231  8469       7381  22944   36.91
# 1               35-55         1120  1792  3800       2721   9433   40.28
# 2                55<=           41    29    92         54    216   42.59
#
# final_result  Withdrawn_%  Fail_%  Distinction_%
# 0                   32.17   22.80           8.12
# 1                   28.85   19.00          11.87
# 2                   25.00   13.43          18.98

# %%
colname = 'region'
tabel(colname, 'final_result', student_info)
# Out:
# final_result                region  Distinction  Fail  Pass  Withdrawn  total  \
# 0              East Anglian Region          327   698  1309       1006   3340
# 1             East Midlands Region          200   462   881        822   2365
# 2                          Ireland           98   261   552        273   1184
# 3                    London Region          263   744  1099       1110   3216
# 4                     North Region          230   327   691        575   1823
# 5             North Western Region          213   704   955       1034   2906
# 6                         Scotland          328   852  1359        907   3446
# 7                South East Region          244   375   843        649   2111
# 8                     South Region          333   544  1287        928   3092
# 9                South West Region          264   465   949        758   2436
# 10                           Wales          177   620   765        524   2086
# 11            West Midlands Region          182   551   936        913   2582
# 12                Yorkshire Region          165   449   735        657   2006
#
# final_result  Pass_%  Withdrawn_%  Fail_%  Distinction_%
# 0              39.19        30.12   20.90           9.79
# 1              37.25        34.76   19.53           8.46
# 2              46.62        23.06   22.04           8.28
# 3              34.17        34.51   23.13           8.18
# 4              37.90        31.54   17.94          12.62
# 5              32.86        35.58   24.23           7.33
# 6              39.44        26.32   24.72           9.52
# 7              39.93        30.74   17.76          11.56
# 8              41.62        30.01   17.59          10.77
# 9              38.96        31.12   19.09          10.84
# 10             36.67        25.12   29.72           8.49
# 11             36.25        35.36   21.34           7.05
# 12             36.64        32.75   22.38           8.23

# %%
colname = 'highest_education'
tabel(colname, 'final_result', student_info)
# Out:
# final_result            highest_education  Distinction  Fail  Pass  Withdrawn  \
# 0                   A Level or Equivalent         1496  2707  5812       4030
# 1                        HE Qualification          697   790  1960       1283
# 2                      Lower Than A Level          727  3426  4385       4620
# 3                         No Formal quals           16    95    87        149
# 4             Post Graduate Qualification           88    34   117         74
#
# final_result  total  Pass_%  Withdrawn_%  Fail_%  Distinction_%
# 0             14045   41.38        28.69   19.27          10.65
# 1              4730   41.44        27.12   16.70          14.74
# 2             13158   33.33        35.11   26.04           5.53
# 3               347   25.07        42.94   27.38           4.61
# 4               313   37.38        23.64   10.86          28.12

# %%
colname = 'studied_credits'
credits = [30, 60, 90, 120, 150, 180, 210, 240, 270, 300]
tab = pd.crosstab(student_info[student_info[colname].isin(credits)][colname], student_info[student_info[colname].isin(credits)].final_result) 

tab.reset_index(level=0, inplace=True)
tab.columns = [colname, 'Distinction', 'Fail', 'Pass', 'Withdrawn']
tab['total'] = tab.Distinction + tab.Fail + tab.Pass + tab.Withdrawn
tab['Distinction_%'] = round(100 * tab['Distinction'] / tab['total'], 2)
tab['Fail_%'] = round(100 * tab['Fail'] / tab['total'], 2)
tab['Pass_%'] = round(100 * tab['Pass'] / tab['total'], 2)
tab['Withdrawn_%'] = round(100 * tab['Withdrawn'] / tab['total'], 2)
tab
# Out:
#    studied_credits  Distinction  Fail  Pass  Withdrawn  total  Distinction_%  \
# 0               30          530  1011  1580        628   3749          14.14
# 1               60         1542  3677  6961       4571  16751           9.21
# 2               90          296   649  1054       1145   3144           9.41
# 3              120          515  1238  2026       2549   6328           8.14
# 4              150           38   151   236        344    769           4.94
# 5              180           32   160   200        438    830           3.86
# 6              210            6    25    37        101    169           3.55
# 7              240            8    26    36        150    220           3.64
# 8              270            2     9     9         25     45           4.44
# 9              300            1     7     5         16     29           3.45
#
#    Fail_%  Pass_%  Withdrawn_%
# 0   26.97   42.14        16.75
# 1   21.95   41.56        27.29
# 2   20.64   33.52        36.42
# 3   19.56   32.02        40.28
# 4   19.64   30.69        44.73
# 5   19.28   24.10        52.77
# 6   14.79   21.89        59.76
# 7   11.82   16.36        68.18
# 8   20.00   20.00        55.56
# 9   24.14   17.24        55.17

# %%
colname = 'imd_band'
tabel(colname, 'final_result', student_info)
# Out:
# final_result imd_band  Distinction  Fail  Pass  Withdrawn  total  Pass_%  \
# 0               0-10%          168   916   996       1231   3311   30.08
# 1               10-20          191   912  1167       1246   3516   33.19
# 2              20-30%          263   844  1226       1321   3654   33.55
# 3              30-40%          315   784  1345       1095   3539   38.01
# 4              40-50%          293   697  1224       1042   3256   37.59
# 5              50-60%          297   701  1227        899   3124   39.28
# 6              60-70%          299   538  1209        859   2905   41.62
# 7              70-80%          313   599  1170        797   2879   40.64
# 8              80-90%          328   495  1165        774   2762   42.18
# 9             90-100%          358   421  1101        656   2536   43.41
# 10                  ?          199   145   531        236   1111   47.79
#
# final_result  Withdrawn_%  Fail_%  Distinction_%
# 0                   37.18   27.67           5.07
# 1                   35.44   25.94           5.43
# 2                   36.15   23.10           7.20
# 3                   30.94   22.15           8.90
# 4                   32.00   21.41           9.00
# 5                   28.78   22.44           9.51
# 6                   29.57   18.52          10.29
# 7                   27.68   20.81          10.87
# 8                   28.02   17.92          11.88
# 9                   25.87   16.60          14.12
# 10                  21.24   13.05          17.91

# %%
colname = 'gender'
tabel(colname, 'final_result', student_info)
# Out:
# final_result gender  Distinction  Fail  Pass  Withdrawn  total  Pass_%  \
# 0                 F         1394  3103  5735       4486  14718   38.97
# 1                 M         1630  3949  6626       5670  17875   37.07
#
# final_result  Withdrawn_%  Fail_%  Distinction_%
# 0                   30.48   21.08           9.47
# 1                   31.72   22.09           9.12

# %%
colname = 'code_module'
tabel(colname, 'final_result', student_info)
# Out:
# final_result code_module  Distinction  Fail  Pass  Withdrawn  total  Pass_%  \
# 0                    AAA           44    91   487        126    748   65.11
# 1                    BBB          677  1767  3077       2388   7909   38.91
# 2                    CCC          498   781  1180       1975   4434   26.61
# 3                    DDD          383  1412  2227       2250   6272   35.51
# 4                    EEE          356   562  1294        722   2934   44.10
# 5                    FFF          670  1711  2978       2403   7762   38.37
# 6                    GGG          396   728  1118        292   2534   44.12
#
# final_result  Withdrawn_%  Fail_%  Distinction_%
# 0                   16.84   12.17           5.88
# 1                   30.19   22.34           8.56
# 2                   44.54   17.61          11.23
# 3                   35.87   22.51           6.11
# 4                   24.61   19.15          12.13
# 5                   30.96   22.04           8.63
# 6                   11.52   28.73          15.63

# %%
colname = 'disability'
tabel(colname, 'final_result', student_info)
# Out:
# final_result disability  Distinction  Fail   Pass  Withdrawn  total  Pass_%  \
# 0                     N         2801  6340  11377       8911  29429   38.66
# 1                     Y          223   712    984       1245   3164   31.10
#
# final_result  Withdrawn_%  Fail_%  Distinction_%
# 0                   30.28   21.54           9.52
# 1                   39.35   22.50           7.05

# %%
colname = 'code_presentation'
tabel(colname, 'final_result', student_info)
# Out:
# final_result code_presentation  Distinction  Fail  Pass  Withdrawn  total  \
# 0                        2013B          327  1241  1768       1348   4684
# 1                        2013J          749  2001  3726       2369   8845
# 2                        2014B          784  1833  2574       2613   7804
# 3                        2014J         1164  1977  4293       3826  11260
#
# final_result  Pass_%  Withdrawn_%  Fail_%  Distinction_%
# 0              37.75        28.78   26.49           6.98
# 1              42.13        26.78   22.62           8.47
# 2              32.98        33.48   23.49          10.05
# 3              38.13        33.98   17.56          10.34

# %%
colname = 'num_of_prev_attempts'
tabel(colname, 'final_result', student_info)
# Out:
# final_result  num_of_prev_attempts  Distinction  Fail   Pass  Withdrawn  \
# 0                                0         2857  5731  11148       8685
# 1                                1          143  1009    997       1150
# 2                                2           22   236    170        247
# 3                                3            1    57     31         53
# 4                                4            0    12     13         14
# 5                                5            0     6      2          5
# 6                                6            1     1      0          2
#
# final_result  total  Pass_%  Withdrawn_%  Fail_%  Distinction_%
# 0             28421   39.22        30.56   20.16          10.05
# 1              3299   30.22        34.86   30.59           4.33
# 2               675   25.19        36.59   34.96           3.26
# 3               142   21.83        37.32   40.14           0.70
# 4                39   33.33        35.90   30.77           0.00
# 5                13   15.38        38.46   46.15           0.00
# 6                 4    0.00        50.00   25.00          25.00

# %% [markdown]
# #### Question:
# Are there students who take multiple modules in this dataset? (E.g student A takes AAA, BBB and GGG)

# %%
student_11391 = student_registration['id_student'] == 11391
filter_AAA = student_registration['code_module'] == 'AAA'
student_registration[student_11391]
# Out:
#   code_module code_presentation  id_student date_registration  \
# 0         AAA             2013J       11391              -159
#
#   date_unregistration
# 0                   ?

# %%
module_AAA = student_registration[filter_AAA]
module_AAA[module_AAA.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [code_module, code_presentation, id_student, date_registration, date_unregistration]
# Index: []

# %% [markdown]
# Let's take a look at the breakdown of assessment type for module AAA
#
# TMA = Tutor Marked Assessment
#
# CMA = Computer Marked Assessment

# %%
assessment_breakdown = assessments['code_module'] == 'AAA'
module_A = assessments[assessment_breakdown]
module_A.shape
# Out:
# (12, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'BBB'
module_B = assessments[assessment_breakdown]
module_B.shape
# Out:
# (42, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'CCC'
module_C = assessments[assessment_breakdown]
module_C.shape
# Out:
# (20, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'DDD'
module_D = assessments[assessment_breakdown]
module_D.shape
# Out:
# (35, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'EEE'
module_E = assessments[assessment_breakdown]
module_E.shape
# Out:
# (15, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'FFF'
module_F = assessments[assessment_breakdown]
module_F.shape
# Out:
# (52, 6)

# %%
assessment_breakdown = assessments['code_module'] == 'GGG'
module_G = assessments[assessment_breakdown]
module_G.shape
# Out:
# (30, 6)

# %% [markdown]
# #### Question:
# Exactly how many students take Module AAA?

# %%
filter_A = student_info['code_module'] == 'AAA'
module_A_results = student_info[filter_A]
module_A_results.shape
#748 students who took Module AAA
# Out:
# (748, 12)

# %%
#Return the number of students who registered for each course in every year
student_registration.groupby(['code_module','code_presentation']).size().reset_index(name='Students_enrolled')
# Out:
#    code_module code_presentation  Students_enrolled
# 0          AAA             2013J                383
# 1          AAA             2014J                365
# 2          BBB             2013B               1767
# 3          BBB             2013J               2237
# 4          BBB             2014B               1613
# 5          BBB             2014J               2292
# 6          CCC             2014B               1936
# 7          CCC             2014J               2498
# 8          DDD             2013B               1303
# 9          DDD             2013J               1938
# 10         DDD             2014B               1228
# 11         DDD             2014J               1803
# 12         EEE             2013J               1052
# 13         EEE             2014B                694
# 14         EEE             2014J               1188
# 15         FFF             2013B               1614
# 16         FFF             2013J               2283
# 17         FFF             2014B               1500
# 18         FFF             2014J               2365
# 19         GGG             2013J                952
# 20         GGG             2014B                833
# 21         GGG             2014J                749

# %%
#check total assessments in each courses
assessments.groupby(['code_module','code_presentation']).size().reset_index(name='Total_assessments')
assessments.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type date  weight
# 0         AAA             2013J           1752             TMA   19    10.0
# 1         AAA             2013J           1753             TMA   54    20.0
# 2         AAA             2013J           1754             TMA  117    20.0
# 3         AAA             2013J           1755             TMA  166    20.0
# 4         AAA             2013J           1756             TMA  215    30.0

# %%
student_registration.groupby(['code_module','code_presentation']).size().reset_index(name='Total_date_registration')
# Out:
#    code_module code_presentation  Total_date_registration
# 0          AAA             2013J                      383
# 1          AAA             2014J                      365
# 2          BBB             2013B                     1767
# 3          BBB             2013J                     2237
# 4          BBB             2014B                     1613
# 5          BBB             2014J                     2292
# 6          CCC             2014B                     1936
# 7          CCC             2014J                     2498
# 8          DDD             2013B                     1303
# 9          DDD             2013J                     1938
# 10         DDD             2014B                     1228
# 11         DDD             2014J                     1803
# 12         EEE             2013J                     1052
# 13         EEE             2014B                      694
# 14         EEE             2014J                     1188
# 15         FFF             2013B                     1614
# 16         FFF             2013J                     2283
# 17         FFF             2014B                     1500
# 18         FFF             2014J                     2365
# 19         GGG             2013J                      952
# 20         GGG             2014B                      833
# 21         GGG             2014J                      749

# %%
student_info['region'].value_counts(sort=True)
# Out:
# Scotland                3446
# East Anglian Region     3340
# London Region           3216
# South Region            3092
# North Western Region    2906
# West Midlands Region    2582
# South West Region       2436
# East Midlands Region    2365
# South East Region       2111
# Wales                   2086
# Yorkshire Region        2006
# North Region            1823
# Ireland                 1184
# Name: region, dtype: int64

# %%
objects = ('Scotland', 
           'East Anglian Region', 
           'London Region', 
           'South Region',
           'North Western Region', 
           'West Midlands Region', 
           'South West Region', 
           'East Midlands Region', 
           'South East Region',
           'Wales', 
           'Yorkshire Region',
           'North Region',
           'Ireland' )
y_pos = np.arange(len(objects))
performance = student_info['region'].value_counts(sort=True).to_list()

plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Number')
plt.title('Programming language usage')

plt.show()
